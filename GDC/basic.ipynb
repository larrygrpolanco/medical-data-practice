# %%
import os
import pandas as pd

# Set the data directory
data_dir = "data/tcga-thca"

# List all TSV files in the directory
tsv_files = [f for f in os.listdir(data_dir) if f.endswith('.tsv')]

# Load all TSV files into a dictionary of DataFrames
dataframes = {}
for file in tsv_files:
  file_path = os.path.join(data_dir, file)
  df = pd.read_csv(file_path, sep='\t')
  dataframes[file] = df
# Out:
# File: family_history.tsv
# (47, 13)
#   project.project_id                         cases.case_id cases.submitter_id  \
# 0          TCGA-THCA  00b62df6-1189-4e38-8601-70416e05550d       TCGA-FY-A4B3
# 1          TCGA-THCA  08293bf4-727d-45c2-abbf-1aec3ba1c8a4       TCGA-EL-A4K0
#
#   family_histories.family_history_id  \
# 0                                '--
# 1                                '--
#
#   family_histories.relationship_age_at_diagnosis  \
# 0                                            '--
# 1                                            '--
#
#   family_histories.relationship_gender  \
# 0                                  '--
# 1                                  '--
#
#   family_histories.relationship_primary_diagnosis  \
# 0                                  Thyroid Cancer
# 1                                  Thyroid Cancer
#
#   family_histories.relationship_type family_histories.relative_deceased  \
# 0                            Unknown                                '--
# 1                            Unknown                                '--
#
#   family_histories.relative_smoker  \
# 0                              '--
# 1                              '--
#
#   family_histories.relative_with_cancer_history  \
# 0                                       unknown
# 1                                       unknown
#
#   family_histories.relatives_with_cancer_history_count  \
# 0                                                '--
# 1                                                '--
#
#   family_histories.submitter_id
# 0                           '--
# 1                           '--
# ----------------------------------------
# File: pathology_detail.tsv
# (507, 86)
#   project.project_id                         cases.case_id cases.submitter_id  \
# 0          TCGA-THCA  00a02e62-e1ab-467a-91b3-5f526dd2251a       TCGA-EL-A3N3
# 1          TCGA-THCA  00b62df6-1189-4e38-8601-70416e05550d       TCGA-FY-A4B3
#
#                  diagnoses.diagnosis_id  diagnoses.submitter_id  \
# 0  be0c76ca-f9f8-5297-a21d-83a4e83797aa  TCGA-EL-A3N3_diagnosis
# 1  034d8c8c-fc73-5f64-ae17-47e1d12c2052  TCGA-FY-A4B3_diagnosis
#
#   pathology_details.additional_pathology_findings  \
# 0                                             '--
# 1                                             '--
#
#   pathology_details.anaplasia_present  \
# 0                                 '--
# 1                                 '--
#
#   pathology_details.anaplasia_present_type  \
# 0                                      '--
# 1                                      '--
#
#   pathology_details.bone_marrow_malignant_cells  \
# 0                                           '--
# 1                                           '--
#
#   pathology_details.breslow_thickness  ...  \
# 0                                 '--  ...
# 1                                 '--  ...
#
#   pathology_details.tumor_infiltrating_macrophages  \
# 0                                              '--
# 1                                              '--
#
#   pathology_details.tumor_largest_dimension_diameter  \
# 0                                                '--
# 1                                                '--
#
#   pathology_details.tumor_length_measurement  \
# 0                                        6.0
# 1                                        2.1
#
#   pathology_details.tumor_level_prostate pathology_details.tumor_shape  \
# 0                                    '--                           '--
# 1                                    '--                           '--
#
#   pathology_details.tumor_thickness pathology_details.tumor_width_measurement  \
# 0                               '--                                       4.5
# 1                               '--                                       1.5
#
#   pathology_details.vascular_invasion_present  \
# 0                                         '--
# 1                                         '--
#
#   pathology_details.vascular_invasion_type  \
# 0                                      '--
# 1                                      '--
#
#   pathology_details.zone_of_origin_prostate
# 0                                       '--
# 1                                       '--
#
# [2 rows x 86 columns]
# ----------------------------------------
# File: clinical.tsv
# (2344, 210)
#   project.project_id                         cases.case_id cases.consent_type  \
# 0          TCGA-THCA  00a02e62-e1ab-467a-91b3-5f526dd2251a   Informed Consent
# 1          TCGA-THCA  00a02e62-e1ab-467a-91b3-5f526dd2251a   Informed Consent
#
#   cases.days_to_consent cases.days_to_lost_to_followup  \
# 0                    -1                            '--
# 1                    -1                            '--
#
#              cases.disease_type cases.index_date cases.lost_to_followup  \
# 0  Adenomas and Adenocarcinomas        Diagnosis                     No
# 1  Adenomas and Adenocarcinomas        Diagnosis                     No
#
#   cases.primary_site cases.submitter_id  ...  treatments.treatment_duration  \
# 0      Thyroid gland       TCGA-EL-A3N3  ...                            '--
# 1      Thyroid gland       TCGA-EL-A3N3  ...                            '--
#
#    treatments.treatment_effect treatments.treatment_effect_indicator  \
# 0                          '--                                   '--
# 1                          '--                                   '--
#
#   treatments.treatment_frequency               treatments.treatment_id  \
# 0                            '--  2b8e17b0-6707-4709-9037-c638f4f8f186
# 1                            '--  7ed22d10-3b18-4830-a56f-c8795a2ef581
#
#   treatments.treatment_intent_type  treatments.treatment_or_therapy  \
# 0                              '--                              yes
# 1                              '--                               no
#
#   treatments.treatment_outcome treatments.treatment_outcome_duration  \
# 0                          '--                                   '--
# 1                          '--                                   '--
#
#      treatments.treatment_type
# 0                 Surgery, NOS
# 1  Pharmaceutical Therapy, NOS
#
# [2 rows x 210 columns]
# ----------------------------------------
# File: follow_up.tsv
# (2966, 198)
#   project.project_id                         cases.case_id cases.submitter_id  \
# 0          TCGA-THCA  00a02e62-e1ab-467a-91b3-5f526dd2251a       TCGA-EL-A3N3
# 1          TCGA-THCA  00a02e62-e1ab-467a-91b3-5f526dd2251a       TCGA-EL-A3N3
#
#   follow_ups.adverse_event follow_ups.adverse_event_grade  \
# 0                      '--                            '--
# 1                      '--                            '--
#
#   follow_ups.aids_risk_factors  \
# 0                          '--
# 1                          '--
#
#   follow_ups.barretts_esophagus_goblet_cells_present follow_ups.bmi  \
# 0                                                '--            '--
# 1                                                '--            '--
#
#   follow_ups.body_surface_area follow_ups.cause_of_response  ...  \
# 0                          '--                          '--  ...
# 1                          '--                          '--  ...
#
#   other_clinical_attributes.undescended_testis_corrected_age  \
# 0                                                '--
# 1                                                '--
#
#   other_clinical_attributes.undescended_testis_corrected_age_range  \
# 0                                                '--
# 1                                                '--
#
#   other_clinical_attributes.undescended_testis_corrected_laterality  \
# 0                                                '--
# 1                                                '--
#
#   other_clinical_attributes.undescended_testis_corrected_method  \
# 0                                                '--
# 1                                                '--
#
#   other_clinical_attributes.undescended_testis_history  \
# 0                                                '--
# 1                                                '--
#
#   other_clinical_attributes.undescended_testis_history_laterality  \
# 0                                                '--
# 1                                                '--
#
#   other_clinical_attributes.viral_hepatitis_serologies  \
# 0                                                '--
# 1                                                '--
#
#   other_clinical_attributes.viral_hepatitis_serology_tests  \
# 0                                                '--
# 1                                                '--
#
#   other_clinical_attributes.weeks_gestation_at_birth  \
# 0                                                '--
# 1                                                '--
#
#   other_clinical_attributes.weight
# 0                              '--
# 1                              '--
#
# [2 rows x 198 columns]
# ----------------------------------------
# File: exposure.tsv
# (18, 40)
#   project.project_id                         cases.case_id cases.submitter_id  \
# 0          TCGA-THCA  1f6be7ca-76fd-4509-99a6-dfa59b0ac51f       TCGA-EM-A2OZ
# 1          TCGA-THCA  2ce580e9-4d75-464c-b403-c9f4626d7aa4       TCGA-DJ-A2PR
#
#   exposures.age_at_last_exposure exposures.age_at_onset  \
# 0                            '--                    '--
# 1                            '--                    '--
#
#   exposures.alcohol_days_per_week exposures.alcohol_drinks_per_day  \
# 0                             '--                              '--
# 1                             '--                              '--
#
#   exposures.alcohol_frequency exposures.alcohol_history  \
# 0                         '--                       '--
# 1                         '--                       '--
#
#   exposures.alcohol_intensity  ... exposures.smoking_frequency  \
# 0                         '--  ...                         '--
# 1                         '--  ...                         '--
#
#   exposures.submitter_id exposures.time_between_waking_and_first_smoke  \
# 0                    '--                                           '--
# 1                    '--                                           '--
#
#   exposures.tobacco_smoking_onset_year exposures.tobacco_smoking_quit_year  \
# 0                                  '--                                 '--
# 1                                  '--                                 '--
#
#   exposures.tobacco_smoking_status exposures.type_of_smoke_exposure  \
# 0                              '--                              '--
# 1                              '--                              '--
#
#   exposures.type_of_tobacco_used exposures.use_per_day exposures.years_smoked
# 0                            '--                   '--                    '--
# 1                            '--                   '--                    '--
#
# [2 rows x 40 columns]
# ----------------------------------------
